# %%
# Cell 1: 
#A set of experiments designed to see how different gain metrics impacts the performance of CON-FOLD.
#We can use XG-Boost as a control
#There also exists data from FOLD-SE that I can compare to later (it uses a Magic Gini Impurity Metric)
#Key metrics:
#1.) Accuracy
#2.) Inverse Brier Score (a metric I designed earlier)
#3.) Time to run (either CPU time or Wall time), it would be great if we could measure/estimate FLOPs but this is not high priority.
#4.) Number of rules produced
#5.) Number of predictes (if we can easily get this)
#Let's try it with both fit and confidence_fit (we use the existing default pruning parameters for confidence fit)
# Let's use all of these datasets:

import numpy as np
import pandas as pd
import time
import os
import sqlite3
from statistics import mean, stdev
from joblib import Parallel, delayed
from IPython.display import display

# Import your project files
# Ensure they are in the python path
metric_list = ['original','information_gain', 'Gini_Impurity', 'Precision_Information_Gain', 'Precision_Gini_Impurity', 'TP_Information_Gain', 'TP_Gini_Impurity']
from foldrm import Classifier
from utils import split_data, split_xy, get_scores, count_rules_in_model, num_predicates, prune_rules, get_inverse_brier_score
from datasets import wine, ecoli, weight_lifting, wall_robot, page_blocks, nursery, dry_bean

datasets = [wine, ecoli, weight_lifting, wall_robot, page_blocks, nursery, dry_bean]
dataset_names = ["Wine", "Ecoli", "Weight Lifting", "Wall Robot", "Page Blocks", "Nursery", "Dry Bean"]


# Display options for the final DataFrame
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 1000)

number_of_trials = 10
# Out:
# C:\Users\Lachlan McGinness\GithubRepositories\CONFOLD\algo.py:2: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.3)
#   from scipy.stats import binom

# %%
# Cell 2: Helper functions (Updated for individual trial handling)
import sqlite3

def run_one_trial(dataset_name, metric, fit_method, data, model_template, num_classes, is_confidence, db_file):
    """
    Runs a single trial and saves the results directly to the SQLite database.
    """
    start_time = time.time()
    
    model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)
    data_train, data_test = split_data(data, ratio=0.8)
    X_test, Y_test = split_xy(data_test)
    
    if is_confidence:
        model.confidence_fit(data_train, metric=metric, num_classes=num_classes)
        # model.rules = prune_rules(model.rules, confidence_threshold=0.75)  # Default pruning (commented as in original)
    else:
        model.fit(data_train, ratio=0.5, metric=metric, num_classes=num_classes)
    
    Ystar_test_tuples = model.predict(X_test)
    Ystar_test = [y[0] for y in Ystar_test_tuples]
    score = get_scores(Ystar_test, data_test)
    brier_score = get_inverse_brier_score(Ystar_test_tuples, Y_test)
    
    rule_count = count_rules_in_model(model)
    
    model.asp()
    predicate_count = num_predicates(model)
    
    elapsed_time = time.time() - start_time
    
    # Save to database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    cursor.execute('PRAGMA journal_mode=WAL;')
    cursor.execute('''
        INSERT INTO trials (dataset, metric, fit_method, accuracy, brier_score, time, num_rules, num_preds)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    ''', (dataset_name, metric, fit_method, score, brier_score, elapsed_time, rule_count, predicate_count))
    conn.commit()
    conn.close()

def run_experiments_for_combination(dataset_info, metric, fit_method, remaining_trials, db_file):
    """
    Runs the remaining trials for a specific dataset, metric, and fit method in parallel.
    """
    dataset_func, name = dataset_info
    print(f"--- Starting: Dataset='{name}', Metric='{metric}', Fit Method='{fit_method}', Remaining Trials={remaining_trials} ---")
    
    model_template, data = dataset_func()
    num_classes = len(pd.unique(pd.DataFrame(data).iloc[:, -1]))
    is_confidence = (fit_method == "CON-FOLD (confidence_fit)")
    
    if remaining_trials > 0:
        Parallel(n_jobs=-1, verbose=10)(
            delayed(run_one_trial)(name, metric, fit_method, data, model_template, num_classes, is_confidence, db_file)
            for _ in range(remaining_trials)
        )
    
    print(f"--- Finished: Dataset='{name}', Metric='{metric}', Fit Method='{fit_method}' ---")

# %%
# Cell 3: SETUP AND SMART RESUME WITH PROGRESSIVE SAVING VIA SQLITE (Updated)
if __name__ == "__main__":
    datasets_with_names = list(zip(datasets, dataset_names))
    NUM_TRIALS = number_of_trials
    db_file = 'experiment_2_trials.db'
    fit_methods = ["FOLD-RM (fit)", "CON-FOLD (confidence_fit)"]

    # Create database and table if not exists
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS trials (
            dataset TEXT,
            metric TEXT,
            fit_method TEXT,
            accuracy REAL,
            brier_score REAL,
            time REAL,
            num_rules INTEGER,
            num_preds INTEGER
        )
    ''')
    conn.commit()

    # Get current counts for each combination
    counts = {}
    cursor.execute('''
        SELECT dataset, metric, fit_method, COUNT(*) 
        FROM trials 
        GROUP BY dataset, metric, fit_method
    ''')
    for row in cursor.fetchall():
        ds, met, fm, cnt = row
        counts[(ds, met, fm)] = cnt
    conn.close()

    # Create list of tasks to run (only remaining trials)
    tasks_to_run = []
    for dataset_info in datasets_with_names:
        name = dataset_info[1]
        for metric in metric_list:
            for fm in fit_methods:
                key = (name, metric, fm)
                current = counts.get(key, 0)
                remaining = NUM_TRIALS - current
                if remaining > 0:
                    tasks_to_run.append({
                        'dataset_info': dataset_info,
                        'metric': metric,
                        'fit_method': fm,
                        'remaining_trials': remaining,
                        'db_file': db_file
                    })

    print(f"\n>>> Total combinations with remaining trials: {len(tasks_to_run)} <<<\n")

    # Run tasks sequentially (inner parallelization handles concurrency)
    if tasks_to_run:
        for task in tasks_to_run:
            run_experiments_for_combination(**task)
        
        print("\n--- All tasks complete! You can now run the aggregation in the next cell. ---")
    else:
        print("\n--- No remaining trials to run. Everything is complete. ---")
# Out:
# >>> Total combinations with remaining trials: 69 <<<
#
# --- Starting: Dataset='Wine', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wine dataset (178, 14)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wine', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wine', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wine dataset (178, 14)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.3s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wine', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wine', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wine dataset (178, 14)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.5s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.5s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wine', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wine', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wine dataset (178, 14)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   11.6s remaining:   27.3s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   12.6s remaining:   12.6s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   14.0s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   15.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wine', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Ecoli', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % ecoli dataset (336, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.3s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.024108171463012695s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.0s remaining:    0.0s
# --- Finished: Dataset='Ecoli', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Ecoli', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % ecoli dataset (336, 9)
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Ecoli', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Ecoli', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % ecoli dataset (336, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.3s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Ecoli', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Ecoli', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % ecoli dataset (336, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.3s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    2.5s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.1s finished
# --- Finished: Dataset='Ecoli', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Weight Lifting', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % weight lifting dataset (4024, 155)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed: 22.5min remaining: 52.5min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed: 23.0min remaining: 23.0min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed: 23.2min remaining:  9.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 23.5min finished
# --- Finished: Dataset='Weight Lifting', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Weight Lifting', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % weight lifting dataset (4024, 155)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   12.1s remaining:   28.3s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   12.6s remaining:   12.6s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   13.2s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   13.3s finished
# --- Finished: Dataset='Weight Lifting', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Weight Lifting', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % weight lifting dataset (4024, 155)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.7s remaining:    8.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.8s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    4.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    4.0s finished
# --- Finished: Dataset='Weight Lifting', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Weight Lifting', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % weight lifting dataset (4024, 155)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   12.1s remaining:   28.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   12.6s remaining:   12.6s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   13.1s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   13.2s finished
# --- Finished: Dataset='Weight Lifting', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Weight Lifting', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % weight lifting dataset (4024, 155)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed: 10.3min remaining: 24.1min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed: 16.7min remaining: 16.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed: 19.3min remaining:  8.3min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 23.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Weight Lifting', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='original', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   16.3s remaining:   38.1s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   16.5s remaining:   16.5s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   17.0s remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   17.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='original', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='original', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   19.4s remaining:   45.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   20.0s remaining:   20.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   20.7s remaining:    8.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   21.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='original', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='information_gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   19.4s remaining:   45.4s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   20.9s remaining:   20.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   21.0s remaining:    9.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   21.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='information_gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   17.1s remaining:   40.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   17.3s remaining:   17.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   18.1s remaining:    7.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   18.3s finished
# --- Finished: Dataset='Wall Robot', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.0s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.1s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.9s remaining:    1.6s
# --- Finished: Dataset='Wall Robot', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    6.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   18.7s remaining:   43.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   18.8s remaining:   18.8s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   19.0s remaining:    8.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   19.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   18.3s remaining:   42.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   19.1s remaining:   19.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   19.3s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   19.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.7min remaining:  3.9min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.8min remaining:   45.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   18.5s remaining:   43.4s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   19.0s remaining:   19.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   20.0s remaining:    8.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   20.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.3s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   17.8s remaining:   41.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   18.2s remaining:   18.2s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   19.1s remaining:    8.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   19.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Wall Robot', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % wall_following_robot dataset (5456, 25)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  3.5min remaining:  8.1min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  5.7min remaining:  5.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  7.2min remaining:  3.1min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  8.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Wall Robot', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='original', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.4s remaining:    8.1s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    4.0s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    4.4s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    4.5s finished
# --- Finished: Dataset='Page Blocks', Metric='original', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='original', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.0s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    2.3s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    2.6s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='original', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='information_gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    4.0s remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    4.4s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    4.8s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    5.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='information_gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.8s remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.2s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.2s remaining:    7.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.7s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    4.1s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    4.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.3s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.8s remaining:    6.6s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.2s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1461484432220459s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.1s remaining:    0.1s
# --- Finished: Dataset='Page Blocks', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.0s remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.2s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.5s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    7.9s remaining:   18.6s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    8.9s remaining:    8.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   12.0s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   22.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    2.9s remaining:    7.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.3s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    4.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.13217663764953613s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.1s remaining:    0.3s
# --- Finished: Dataset='Page Blocks', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.3s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    4.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    4.7s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    5.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Page Blocks', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % page blocks dataset (5473, 11)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   18.3s remaining:   42.9s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   18.4s remaining:   18.4s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   22.5s remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   50.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Page Blocks', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='original', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    1.0s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='original', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='original', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    1.4s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.8s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    2.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='original', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='information_gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.8s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='information_gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.4s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.7s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    1.0s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.2s finished
# --- Finished: Dataset='Nursery', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1546342372894287s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   42.4s remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.1min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.1min remaining:   29.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Nursery', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    0.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# --- Finished: Dataset='Nursery', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Nursery', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % nursery dataset (12960, 9)
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.6min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  2.1min remaining:   53.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  4.7min finished
# --- Finished: Dataset='Nursery', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='original', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.5min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.6min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.6min remaining:   42.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.8min finished
# --- Finished: Dataset='Dry Bean', Metric='original', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='original', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.8min remaining:  4.1min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.8min remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.9min remaining:   47.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.9min finished
# --- Finished: Dataset='Dry Bean', Metric='original', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='information_gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.4min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.5min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.6min remaining:   40.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.7min finished
# --- Finished: Dataset='Dry Bean', Metric='information_gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    3.0s remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    3.1s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.1s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.2s finished
# --- Finished: Dataset='Dry Bean', Metric='information_gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.6min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.6min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.6min remaining:   41.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.7min finished
# --- Finished: Dataset='Dry Bean', Metric='Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed: 20.6min remaining: 48.2min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed: 33.0min remaining: 33.0min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed: 51.6min remaining: 22.1min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 86.6min finished
# --- Finished: Dataset='Dry Bean', Metric='Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.5min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.6min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.6min remaining:   41.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.7min finished
# --- Finished: Dataset='Dry Bean', Metric='Precision_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    4.8s remaining:   11.4s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    4.9s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    5.0s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    5.1s finished
# --- Finished: Dataset='Dry Bean', Metric='Precision_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.6min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.8min remaining:   45.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.8min finished
# --- Finished: Dataset='Dry Bean', Metric='Precision_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed: 21.9min remaining: 51.2min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed: 22.7min remaining: 22.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed: 25.2min remaining: 10.8min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 29.2min finished
# --- Finished: Dataset='Dry Bean', Metric='Precision_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.4min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.5min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.5min remaining:   38.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.6min finished
# --- Finished: Dataset='Dry Bean', Metric='TP_Information_Gain', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    1.9s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.9s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.9s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.0s finished
# --- Finished: Dataset='Dry Bean', Metric='TP_Information_Gain', Fit Method='CON-FOLD (confidence_fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.6min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.7min remaining:   43.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.7min finished
# --- Finished: Dataset='Dry Bean', Metric='TP_Gini_Impurity', Fit Method='FOLD-RM (fit)' ---
# --- Starting: Dataset='Dry Bean', Metric='TP_Gini_Impurity', Fit Method='CON-FOLD (confidence_fit)', Remaining Trials=10 ---
#
# % dry bean dataset (13611, 17)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed: 204.8min remaining: 477.8min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed: 258.2min remaining: 258.2min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed: 356.4min remaining: 152.8min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 60
#      58 if tasks_to_run:
#      59     for task in tasks_to_run:
# ---> 60         run_experiments_for_combination(**task)
#      62     print("\n--- All tasks complete! You can now run the aggregation in the next cell. ---")
#      63 else:
#
# Cell In[2], line 55, in run_experiments_for_combination(dataset_info, metric, fit_method, remaining_trials, db_file)
#      52 is_confidence = (fit_method == "CON-FOLD (confidence_fit)")
#      54 if remaining_trials > 0:
# ---> 55     Parallel(n_jobs=-1, verbose=10)(
#      56         delayed(run_one_trial)(name, metric, fit_method, data, model_template, num_classes, is_confidence, db_file)
#      57         for _ in range(remaining_trials)
#      58     )
#      60 print(f"--- Finished: Dataset='{name}', Metric='{metric}', Fit Method='{fit_method}' ---")
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    datasets_with_names = list(zip(datasets, dataset_names))
    NUM_TRIALS = number_of_trials
    db_file = 'experiment_2_trials.db'
    fit_methods = ["FOLD-RM (fit)", "CON-FOLD (confidence_fit)"]
    
    # LIMIT TO 8 CORES MAXIMUM
    MAX_CORES = 8
    
    # HARD-CODED SKIP LIST FOR KNOWN SLOW/FAILURE COMBINATIONS
    # Add tuples of (dataset_name, metric, fit_method) to skip
    skip_combinations = [
        ('Dry Bean', 'Gini_Impurity_Covered', 'CON-FOLD (confidence_fit)'),
        # Add more here as needed, e.g., ('Another Dataset', 'Some Metric', 'Some Method')
    ]

    # Create database and table if not exists
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS trials (
            dataset TEXT,
            metric TEXT,
            fit_method TEXT,
            accuracy REAL,
            brier_score REAL,
            time REAL,
            num_rules INTEGER,
            num_preds INTEGER
        )
    ''')
    conn.commit()

    # Get current counts for each combination
    counts = {}
    cursor.execute('''
        SELECT dataset, metric, fit_method, COUNT(*) 
        FROM trials 
        GROUP BY dataset, metric, fit_method
    ''')
    for row in cursor.fetchall():
        ds, met, fm, cnt = row
        counts[(ds, met, fm)] = cnt
    conn.close()

    # Create list of tasks to run (only remaining trials, skipping known issues)
    tasks_to_run = []
    skipped = []
    for dataset_info in datasets_with_names:
        name = dataset_info[1]
        for metric in metric_list:
            for fm in fit_methods:
                key = (name, metric, fm)
                if key in skip_combinations:
                    skipped.append(key)
                    continue
                current = counts.get(key, 0)
                remaining = NUM_TRIALS - current
                if remaining > 0:
                    tasks_to_run.append({
                        'dataset_info': dataset_info,
                        'metric': metric,
                        'fit_method': fm,
                        'remaining_trials': remaining,
                        'db_file': db_file
                    })

    print(f"\n>>> LIGHTWEIGHT MODE: Total combinations with remaining trials: {len(tasks_to_run)} <<<")
    if skipped:
        print(">>> SKIPPED COMBINATIONS (known slow/failures):")
        for sk in skipped:
            print(f"    - Dataset='{sk[0]}', Metric='{sk[1]}', Fit='{sk[2]}'")
    print(f">>> Using MAX {MAX_CORES} cores - Trial-by-trial progress tracking ENABLED <<<")
    print(f">>> You can STOP anytime (Ctrl+C) and resume from here later <<<")

    # Run tasks sequentially with limited parallelism and detailed tracking
    if tasks_to_run:
        total_remaining = sum(task['remaining_trials'] for task in tasks_to_run)
        completed_trials = 0
        
        for task_idx, task in enumerate(tasks_to_run, 1):
            dataset_info, metric, fit_method, remaining_trials, db_file = (
                task['dataset_info'], task['metric'], task['fit_method'], 
                task['remaining_trials'], task['db_file']
            )
            dataset_func, name = dataset_info
            
            print(f"\n{'='*80}")
            print(f"TASK {task_idx}/{len(tasks_to_run)}: Dataset='{name}', Metric='{metric}', Fit='{fit_method}'")
            print(f"Remaining trials for this task: {remaining_trials}")
            print(f"Overall progress: {completed_trials}/{total_remaining} ({100*completed_trials/total_remaining:.1f}%)")
            print(f"{'='*80}")
            
            # Pre-load data and model template (once per task)
            model_template, data = dataset_func()
            num_classes = len(pd.unique(pd.DataFrame(data).iloc[:, -1]))
            is_confidence = (fit_method == "CON-FOLD (confidence_fit)")
            
            # Run trials in SMALL BATCHES with progress tracking
            batch_size = MAX_CORES  # Process MAX_CORES trials at a time
            for batch_start in range(0, remaining_trials, batch_size):
                batch_end = min(batch_start + batch_size, remaining_trials)
                batch_size_actual = batch_end - batch_start
                
                print(f"\n  -> Batch {batch_start//batch_size + 1}: Trials {batch_start+1} to {batch_end}/{remaining_trials}")
                
                # Run batch with LIMITED cores
                results = Parallel(n_jobs=MAX_CORES, verbose=0)(
                    delayed(run_one_trial)(name, metric, fit_method, data, model_template, 
                                         num_classes, is_confidence, db_file)
                    for _ in range(batch_size_actual)
                )
                
                # Update progress
                completed_trials += batch_size_actual
                print(f"  Batch complete! Trial {batch_end}/{remaining_trials} (Overall: {completed_trials}/{total_remaining})")
                
                # Print detailed trial summary every batch
                print(f"  Current task: {batch_end}/{remaining_trials} | "
                      f"Overall: {completed_trials}/{total_remaining} ({100*completed_trials/total_remaining:.1f}%)")
            
            print(f"TASK {task_idx}/{len(tasks_to_run)} COMPLETE: Dataset='{name}'")
        
        print(f"\n ALL TASKS COMPLETE! Total trials: {completed_trials}/{total_remaining}")
        print("\n--- You can now run the aggregation in the next cell. ---")
        
    else:
        print("\n--- No remaining trials to run. Everything is complete. ---")

# %%
# This cell aggregates the trial data from the database, computes averages/std, and saves to the backup CSV.

backup_file = 'experiment_2_results_backup.csv'
db_file = 'experiment_2_trials.db'
NUM_TRIALS = number_of_trials

# 1. Load all trial data from the database
conn = sqlite3.connect(db_file)
# Use a try-except block to handle the case where the table doesn't exist yet
try:
    all_trials_df = pd.read_sql_query("SELECT * FROM trials", conn)
except pd.io.sql.DatabaseError:
    all_trials_df = pd.DataFrame() # Create an empty DataFrame if no table exists
conn.close()

if not all_trials_df.empty:
    # 2. Group by experiment combination and calculate aggregates
    agg_functions = {
        'accuracy': ['mean', 'std'],
        'brier_score': ['mean', 'std'],
        'time': ['mean'],
        'num_rules': ['mean', 'std'],
        'num_preds': ['mean', 'std'],
    }
    
    # We also need the count to filter by it
    summary_df = all_trials_df.groupby(['dataset', 'metric', 'fit_method']).agg(agg_functions)
    summary_df['trial_count'] = all_trials_df.groupby(['dataset', 'metric', 'fit_method'])['accuracy'].count()

    # 3. Filter for combinations that are fully complete
    completed_df = summary_df[summary_df['trial_count'] >= NUM_TRIALS].copy()
    
    results_list = []
    if not completed_df.empty:
        # 4. Flatten the MultiIndex columns and format for saving
        completed_df.columns = ['_'.join(col).strip() for col in completed_df.columns.values]
        completed_df.reset_index(inplace=True)

        for _, row in completed_df.iterrows():
            results_list.append({
                "Dataset": row['dataset'],
                "Metric": row['metric'],
                "Fit Method": row['fit_method'],
                "Avg Accuracy": row['accuracy_mean'],
                "Std Accuracy": row['accuracy_std'] if pd.notnull(row['accuracy_std']) else 0,
                "Avg Brier Score": row['brier_score_mean'],
                "Std Brier Score": row['brier_score_std'] if pd.notnull(row['brier_score_std']) else 0,
                "Avg Time": row['time_mean'],
                "Num Rules Avg": row['num_rules_mean'],
                "Num Rules Std": row['num_rules_std'] if pd.notnull(row['num_rules_std']) else 0,
                "Num Preds Avg": row['num_preds_mean'],
                "Num Preds Std": row['num_preds_std'] if pd.notnull(row['num_preds_std']) else 0
            })

    if results_list:
        final_df = pd.DataFrame(results_list)
        final_df.to_csv(backup_file, index=False)
        print(f"--- Aggregated results for {len(final_df)} completed combinations saved to {backup_file} ---")
    else:
        print(f"--- No completed combinations with at least {number_of_trials} trials yet. ---")
else:
    print("--- No trial data found in the database. ---")
# Out:
# --- Aggregated results for 97 completed combinations saved to experiment_2_results_backup.csv ---

# %%
# Cell 5: Process, Display, and Save Results (Original Cell 4, unchanged but renumbered)

def process_and_display_results(df, fit_method_name, filename):
    """
    Helper function to pivot, average, format, display, and save results.
    """
    # --- 1. Pivot the DataFrame (Datasets as Columns) ---
    pivoted_df = df.set_index(['Metric', 'Fit Method', 'Dataset'])
    pivoted_df = pivoted_df.unstack(level='Dataset')
    pivoted_df = pivoted_df.swaplevel(0, 1, axis=1)
    pivoted_df.sort_index(axis=1, level=0, inplace=True)
    
    # --- 2. Calculate the Average Across All Datasets ---
    average_df = df.groupby(['Metric', 'Fit Method']).mean(numeric_only=True)
    average_df.columns = pd.MultiIndex.from_product([['Average'], average_df.columns])
    
    # --- 3. Combine Average and Pivoted DataFrames ---
    final_summary_df = pd.concat([average_df, pivoted_df], axis=1)
    
    # --- 4. Format the DataFrame for Display ---
    format_dict = {
        "Accuracy Avg": "{:.4f}",
        "Accuracy Std": "{:.4f}",
        "Brier Score Avg": "{:.4f}", # Added Brier format
        "Brier Score Std": "{:.4f}", # Added Brier format
        "Avg Time": "{:.3f}s",
        "Num Rules Avg": "{:.2f}",
        "Num Rules Std": "{:.2f}",
        "Num Preds Avg": "{:.2f}",
        "Num Preds Std": "{:.2f}"
    }
    
    # Explicitly list columns to apply bar charts to
    accuracy_cols = [col for col in final_summary_df.columns if col[1] == 'Avg Accuracy']
    brier_cols = [col for col in final_summary_df.columns if col[1] == 'Avg Brier Score']

    formatted_df = final_summary_df.style.format(format_dict) \
        .bar(subset=accuracy_cols, color='#5fba7d', vmin=0.5) \
        .bar(subset=brier_cols, color='#c9a1e8', vmin=0.5)
    
    print(f"\n--- EXPERIMENT SUMMARY: {fit_method_name} ---")
    display(formatted_df)
    
    # --- 5. Save the Summary to a CSV file ---
    final_summary_df.to_csv(filename)
    print(f"\nSummary results have been successfully saved to {filename}")


# --- Main Processing ---
# Create the initial "long format" DataFrame from the list of dictionaries
# Note: Load from the aggregated backup CSV (produced by new Cell 4)
backup_file = 'experiment_2_results_backup.csv'
if os.path.exists(backup_file):
    results_df_long = pd.read_csv(backup_file)
else:
    results_df_long = pd.DataFrame()
    print("--- No aggregated results yet. Run Cell 4 after experiments. ---")

if not results_df_long.empty:
    # Process FOLD-RM (fit) results
    fold_rm_df = results_df_long[results_df_long['Fit Method'] == 'FOLD-RM (fit)'].copy()
    process_and_display_results(fold_rm_df, "FOLD-RM (fit)", "fold_rm_metric_summary.csv")

    # Process CON-FOLD (confidence_fit) results
    con_fold_df = results_df_long[results_df_long['Fit Method'] == 'CON-FOLD (confidence_fit)'].copy()
    process_and_display_results(con_fold_df, "CON-FOLD (confidence_fit)", "con_fold_metric_summary.csv")
else:
    print("--- No data to process yet. ---")
# Out:
# --- EXPERIMENT SUMMARY: FOLD-RM (fit) ---
# <style type="text/css">
# #T_73f13_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 97.8%, transparent 97.8%);
# }
# #T_73f13_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.0%, transparent 99.0%);
# }
# #T_73f13_row0_col9, #T_73f13_row0_col45, #T_73f13_row3_col0, #T_73f13_row4_col36, #T_73f13_row4_col45 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.7%, transparent 99.7%);
# }
# #T_73f13_row0_col10, #T_73f13_row3_col2, #T_73f13_row4_col46, #T_73f13_row4_col55, #T_73f13_row6_col19, #T_73f13_row6_col46 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.8%, transparent 99.8%);
# }
# #T_73f13_row0_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 87.3%, transparent 87.3%);
# }
# #T_73f13_row0_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 95.1%, transparent 95.1%);
# }
# #T_73f13_row0_col27 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.3%, transparent 98.3%);
# }
# #T_73f13_row0_col28, #T_73f13_row5_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 98.7%, transparent 98.7%);
# }
# #T_73f13_row0_col36, #T_73f13_row4_col9, #T_73f13_row5_col45 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.4%, transparent 99.4%);
# }
# #T_73f13_row0_col37, #T_73f13_row1_col37, #T_73f13_row2_col37, #T_73f13_row2_col64, #T_73f13_row3_col46, #T_73f13_row4_col28, #T_73f13_row5_col2, #T_73f13_row5_col46 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.4%, transparent 99.4%);
# }
# #T_73f13_row0_col46 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.7%, transparent 99.7%);
# }
# #T_73f13_row0_col54, #T_73f13_row1_col54, #T_73f13_row2_col0, #T_73f13_row2_col18, #T_73f13_row2_col45, #T_73f13_row2_col54, #T_73f13_row2_col63, #T_73f13_row3_col9, #T_73f13_row3_col36, #T_73f13_row3_col54, #T_73f13_row3_col63, #T_73f13_row5_col54, #T_73f13_row6_col27, #T_73f13_row6_col54 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_73f13_row0_col55, #T_73f13_row1_col55, #T_73f13_row5_col55, #T_73f13_row6_col2, #T_73f13_row6_col55 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.9%, transparent 99.9%);
# }
# #T_73f13_row0_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 94.4%, transparent 94.4%);
# }
# #T_73f13_row0_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 96.5%, transparent 96.5%);
# }
# #T_73f13_row1_col0, #T_73f13_row5_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.5%, transparent 98.5%);
# }
# #T_73f13_row1_col2, #T_73f13_row1_col10, #T_73f13_row5_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.1%, transparent 99.1%);
# }
# #T_73f13_row1_col9, #T_73f13_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.0%, transparent 99.0%);
# }
# #T_73f13_row1_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 93.2%, transparent 93.2%);
# }
# #T_73f13_row1_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 96.3%, transparent 96.3%);
# }
# #T_73f13_row1_col27, #T_73f13_row5_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.1%, transparent 98.1%);
# }
# #T_73f13_row1_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 98.4%, transparent 98.4%);
# }
# #T_73f13_row1_col36, #T_73f13_row2_col36, #T_73f13_row6_col36 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.6%, transparent 99.6%);
# }
# #T_73f13_row1_col45 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.5%, transparent 99.5%);
# }
# #T_73f13_row1_col46, #T_73f13_row4_col10, #T_73f13_row6_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.5%, transparent 99.5%);
# }
# #T_73f13_row1_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 96.3%, transparent 96.3%);
# }
# #T_73f13_row1_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 97.7%, transparent 97.7%);
# }
# #T_73f13_row2_col2, #T_73f13_row2_col19, #T_73f13_row2_col46, #T_73f13_row2_col55, #T_73f13_row3_col10, #T_73f13_row3_col37, #T_73f13_row3_col55, #T_73f13_row3_col64, #T_73f13_row6_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 100.0%, transparent 100.0%);
# }
# #T_73f13_row2_col9, #T_73f13_row5_col36 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.1%, transparent 99.1%);
# }
# #T_73f13_row2_col10, #T_73f13_row5_col10, #T_73f13_row6_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.2%, transparent 99.2%);
# }
# #T_73f13_row2_col27, #T_73f13_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.2%, transparent 99.2%);
# }
# #T_73f13_row2_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.3%, transparent 99.3%);
# }
# #T_73f13_row3_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 96.6%, transparent 96.6%);
# }
# #T_73f13_row3_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 97.0%, transparent 97.0%);
# }
# #T_73f13_row3_col27 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.7%, transparent 98.7%);
# }
# #T_73f13_row3_col28, #T_73f13_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 98.9%, transparent 98.9%);
# }
# #T_73f13_row3_col45, #T_73f13_row4_col27, #T_73f13_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.3%, transparent 99.3%);
# }
# #T_73f13_row4_col0, #T_73f13_row5_col27 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.4%, transparent 98.4%);
# }
# #T_73f13_row4_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 92.7%, transparent 92.7%);
# }
# #T_73f13_row4_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 93.8%, transparent 93.8%);
# }
# #T_73f13_row4_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 99.6%, transparent 99.6%);
# }
# #T_73f13_row4_col54, #T_73f13_row6_col45 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.8%, transparent 99.8%);
# }
# #T_73f13_row4_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 93.8%, transparent 93.8%);
# }
# #T_73f13_row4_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 96.7%, transparent 96.7%);
# }
# #T_73f13_row5_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 96.1%, transparent 96.1%);
# }
# #T_73f13_row5_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 97.8%, transparent 97.8%);
# }
# #T_73f13_row5_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 98.3%, transparent 98.3%);
# }
# #T_73f13_row6_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.0%, transparent 98.0%);
# }
# #T_73f13_row6_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 95.7%, transparent 95.7%);
# }
# #T_73f13_row6_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 98.0%, transparent 98.0%);
# }
# </style>
# <table id="T_73f13">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73f13_level0_col0" class="col_heading level0 col0" colspan="9">Average</th>
#       <th id="T_73f13_level0_col9" class="col_heading level0 col9" colspan="9">Dry Bean</th>
#       <th id="T_73f13_level0_col18" class="col_heading level0 col18" colspan="9">Ecoli</th>
#       <th id="T_73f13_level0_col27" class="col_heading level0 col27" colspan="9">Nursery</th>
#       <th id="T_73f13_level0_col36" class="col_heading level0 col36" colspan="9">Page Blocks</th>
#       <th id="T_73f13_level0_col45" class="col_heading level0 col45" colspan="9">Wall Robot</th>
#       <th id="T_73f13_level0_col54" class="col_heading level0 col54" colspan="9">Weight Lifting</th>
#       <th id="T_73f13_level0_col63" class="col_heading level0 col63" colspan="9">Wine</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_73f13_level1_col0" class="col_heading level1 col0" >Avg Accuracy</th>
#       <th id="T_73f13_level1_col1" class="col_heading level1 col1"
# Summary results have been successfully saved to fold_rm_metric_summary.csv
#
# --- EXPERIMENT SUMMARY: CON-FOLD (confidence_fit) ---
# <style type="text/css">
# #T_1069b_row0_col0, #T_1069b_row0_col9, #T_1069b_row0_col18, #T_1069b_row0_col27, #T_1069b_row0_col45, #T_1069b_row0_col54, #T_1069b_row0_col63, #T_1069b_row1_col9, #T_1069b_row1_col18, #T_1069b_row1_col27, #T_1069b_row1_col45, #T_1069b_row2_col0, #T_1069b_row2_col9, #T_1069b_row2_col18, #T_1069b_row2_col27, #T_1069b_row2_col36, #T_1069b_row2_col45, #T_1069b_row2_col54, #T_1069b_row2_col63, #T_1069b_row3_col0, #T_1069b_row3_col9, #T_1069b_row3_col10, #T_1069b_row3_col18, #T_1069b_row3_col27, #T_1069b_row3_col45, #T_1069b_row3_col54, #T_1069b_row3_col63, #T_1069b_row4_col0, #T_1069b_row4_col9, #T_1069b_row4_col18, #T_1069b_row4_col27, #T_1069b_row4_col36, #T_1069b_row4_col45, #T_1069b_row4_col54, #T_1069b_row4_col63, #T_1069b_row5_col9, #T_1069b_row5_col45 {
#   width: 10em;
# }
# #T_1069b_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 61.7%, transparent 61.7%);
# }
# #T_1069b_row0_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 60.2%, transparent 60.2%);
# }
# #T_1069b_row0_col19, #T_1069b_row2_col19, #T_1069b_row4_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 70.2%, transparent 70.2%);
# }
# #T_1069b_row0_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 56.2%, transparent 56.2%);
# }
# #T_1069b_row0_col36 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 86.7%, transparent 86.7%);
# }
# #T_1069b_row0_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 88.7%, transparent 88.7%);
# }
# #T_1069b_row0_col46, #T_1069b_row2_col46, #T_1069b_row3_col46, #T_1069b_row4_col46, #T_1069b_row5_col46 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 52.6%, transparent 52.6%);
# }
# #T_1069b_row0_col55, #T_1069b_row2_col55, #T_1069b_row4_col55 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 50.7%, transparent 50.7%);
# }
# #T_1069b_row0_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 54.8%, transparent 54.8%);
# }
# #T_1069b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 9.3%, transparent 9.3%);
# }
# #T_1069b_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 72.9%, transparent 72.9%);
# }
# #T_1069b_row1_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 75.2%, transparent 75.2%);
# }
# #T_1069b_row1_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 81.5%, transparent 81.5%);
# }
# #T_1069b_row1_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 57.1%, transparent 57.1%);
# }
# #T_1069b_row1_col36 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 89.1%, transparent 89.1%);
# }
# #T_1069b_row1_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 90.6%, transparent 90.6%);
# }
# #T_1069b_row1_col46 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 69.1%, transparent 69.1%);
# }
# #T_1069b_row1_col54 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 64.9%, transparent 64.9%);
# }
# #T_1069b_row1_col55 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 72.2%, transparent 72.2%);
# }
# #T_1069b_row1_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 49.1%, transparent 49.1%);
# }
# #T_1069b_row1_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 65.0%, transparent 65.0%);
# }
# #T_1069b_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 58.5%, transparent 58.5%);
# }
# #T_1069b_row2_col10, #T_1069b_row4_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 60.1%, transparent 60.1%);
# }
# #T_1069b_row2_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 69.3%, transparent 69.3%);
# }
# #T_1069b_row2_col37, #T_1069b_row4_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 54.4%, transparent 54.4%);
# }
# #T_1069b_row2_col64, #T_1069b_row4_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 54.6%, transparent 54.6%);
# }
# #T_1069b_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 62.9%, transparent 62.9%);
# }
# #T_1069b_row3_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 70.6%, transparent 70.6%);
# }
# #T_1069b_row3_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 56.1%, transparent 56.1%);
# }
# #T_1069b_row3_col36 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 88.1%, transparent 88.1%);
# }
# #T_1069b_row3_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 89.8%, transparent 89.8%);
# }
# #T_1069b_row3_col55 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 51.1%, transparent 51.1%);
# }
# #T_1069b_row3_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 55.0%, transparent 55.0%);
# }
# #T_1069b_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 58.7%, transparent 58.7%);
# }
# #T_1069b_row4_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 71.2%, transparent 71.2%);
# }
# #T_1069b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 29.0%, transparent 29.0%);
# }
# #T_1069b_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 83.0%, transparent 83.0%);
# }
# #T_1069b_row5_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 66.6%, transparent 66.6%);
# }
# #T_1069b_row5_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 15.7%, transparent 15.7%);
# }
# #T_1069b_row5_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 83.6%, transparent 83.6%);
# }
# #T_1069b_row5_col27 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 86.5%, transparent 86.5%);
# }
# #T_1069b_row5_col28 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 90.3%, transparent 90.3%);
# }
# #T_1069b_row5_col36 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 88.8%, transparent 88.8%);
# }
# #T_1069b_row5_col37 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 90.1%, transparent 90.1%);
# }
# #T_1069b_row5_col54 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 94.0%, transparent 94.0%);
# }
# #T_1069b_row5_col55 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 95.1%, transparent 95.1%);
# }
# #T_1069b_row5_col63, #T_1069b_row6_col0, #T_1069b_row6_col9, #T_1069b_row6_col18, #T_1069b_row6_col27, #T_1069b_row6_col36, #T_1069b_row6_col45, #T_1069b_row6_col54 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_1069b_row5_col64, #T_1069b_row6_col2, #T_1069b_row6_col10, #T_1069b_row6_col19, #T_1069b_row6_col28, #T_1069b_row6_col37, #T_1069b_row6_col46, #T_1069b_row6_col55 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 100.0%, transparent 100.0%);
# }
# #T_1069b_row6_col63 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 93.3%, transparent 93.3%);
# }
# #T_1069b_row6_col64 {
#   width: 10em;
#   background: linear-gradient(90deg, #c9a1e8 98.0%, transparent 98.0%);
# }
# </style>
# <table id="T_1069b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1069b_level0_col0" class="col_heading level0 col0" colspan="9">Average</th>
#       <th id="T_1069b_level0_col9" class="col_heading level0 col9" colspan="9">Dry Bean</th>
#       <th id="T_1069b_level0_col18" class="col_heading level0 col18" colspan="9">Ecoli</th>
#       <th id="T_1069b_level0_col27" class="col_heading level0 col27" colspan="9">Nursery</th>
#       <th id="T_1069b_level0_col36" class="col_heading level0 col36" colspan="9">Page Blocks</th>
#       <th id="T_1069b_level0_col45" class="col_heading level0 col45" colspan="9">Wall Robot</th>
#       <th id="T_1069b_level0_col54" class="col_heading level0 col54" colspan="9">Weight Lifting</th>
#       <th id="T_1069b_level0_col63" class="col_heading level0 col63" colspan="9">Wine</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_1069b_level1_col0" class="col_heading level1 col0" >Avg Accuracy</th>
#       <th id="T_1069b_level1_col1" class="col_headi
# Summary results have been successfully saved to con_fold_metric_summary.csv
