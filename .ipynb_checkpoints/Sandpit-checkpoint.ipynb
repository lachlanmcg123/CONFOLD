# %%
#!conda install --yes --prefix {sys.prefix} scikit-learn -c conda-forge

# %%
# !pip install scipy
# !pip install scikit-learn
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# Import the custom modules from your project
# Ensure these files are in the same directory as your notebook
from datasets import ecoli
from utils import split_data, split_xy

# Load the ecoli dataset and the model structure
# The 'model' object is an untrained instance of the algorithm
# The 'data' object holds the feature and target variables
model, data = ecoli()

print("Setup complete. Ecoli dataset is loaded.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\scipy\__init__.py:98
#      97 try:
# ---> 98     from scipy._lib._ccallback import LowLevelCallable
#      99 except ImportError as e:
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\scipy\_lib\_ccallback.py:1
# ----> 1 from . import _ccallback_c
#       3 import ctypes
#
# ImportError: cannot import name '_ccallback_c' from 'scipy._lib' (C:\Users\Lachlan\.conda\envs\AlphaPhysics\Lib\site-packages\scipy\_lib\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from sklearn.model_selection import StratifiedKFold
#       4 from sklearn.metrics import accuracy_score
#       6 # Import the custom modules from your project
#       7 # Ensure these files are in the same directory as your notebook
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)    114     "compose",
#     115 ]
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from . import metadata_routing
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from ._indexing import (
#      17     _safe_indexing,  # noqa: F401
#      18     resample,
#      19     shuffle,
#      20 )
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\sklearn\utils\_param_validation.py:14
#      11 from numbers import Integral, Real
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
#      17 from .validation import _is_arraylike_not_scalar
#
# File ~\.conda\envs\AlphaPhysics\Lib\site-packages\scipy\__init__.py:103
#      99 except ImportError as e:
#     100     msg = "The `scipy` install you are using seems to be broken, " + \
#     101           "(extension modules cannot be imported), " + \
#     102           "please try reinstalling."
# --> 103     raise ImportError(msg) from e
#     106 from scipy._lib._testutils import PytestTester
#     107 test = PytestTester(__name__)
#
# ImportError: The `scipy` install you are using seems to be broken, (extension modules cannot be imported), please try reinstalling.

# %%
# 1. Split the data into a training set (80%) and a testing set (20%)
data_train, data_test = split_data(data, ratio=0.8)
X_test, Y_test = split_xy(data_test)

# 2. Instantiate a fresh model to train
confold_model, _ = ecoli()

# 3. Train the CON-FOLD model on the training data
# We use the optimized parameters from your notebook for the Ecoli dataset
confold_model.confidence_fit(data_train, improvement_threshold=0.08)
confold_model.rules = prune_rules(confold_model.rules, confidence=0.6)
confold_model.asp() # This method likely finalizes the rule set

# 4. Print the generated rules
print("--- Generated CON-FOLD Rules ---")
if hasattr(confold_model, 'crs') and confold_model.crs:
    for i, rule in enumerate(confold_model.crs):
        # The rule format appears to be [body, head, confidence]
        # We check if confidence is > 0 as done in your notebook
        if rule[-1] > 0:
            print(f"Rule {i+1}: IF {rule[0]} THEN {rule[1]} (Confidence: {rule[-1]:.4f})")
else:
    print("No rules were generated or the attribute 'crs' is not available.")

# 5. Make predictions and evaluate accuracy on the test set
# The predict method returns a list of tuples (predicted_class, confidence)
predictions_with_confidence = confold_model.predict(X_test)
# Extract just the predicted class for accuracy calculation
predictions = [p[0] for p in predictions_with_confidence]

accuracy = accuracy_score(Y_test, predictions)
print("\n--- Model Performance ---")
print(f"Accuracy on the single test set: {accuracy:.4f}")
